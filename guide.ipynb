# %% [markdown]
# # Você precisa instalar os pacotes do guia ou usar colab para executar a biblioteca

# %%
import metamodel as mmodel

# %% [markdown]
# # Como usar

# %%
test = mmodel.metamodel()

# %%
test.cuda_status()
# Out:
# Are you using GPU? False

# %%
test.plot_correlations()

# %%
test.plot_distributions()

# %%
test.fit()
# Out:
# Epoch 1000/epochs, Train Loss: 0.3526 Test Loss: 0.3581
# Sequential(
#   (0): Linear(in_features=5, out_features=5, bias=True)
#   (1): Sigmoid()
#   (2): Linear(in_features=5, out_features=1, bias=True)
# )

# %%
test.train_performance()

# %%
test.model_peformance()

# %% [markdown]
# ### Focar aqui
# Tentem achar um ótimo usando esse formato de 5 entrada

# %%
test.predict([1,1,1,1,1])
# Out:
# array([[0.8695308]], dtype=float32)

# %%
test.predict(np.array([1,1,1,1,1]))
# Out:
# array([0.8695308], dtype=float32)
